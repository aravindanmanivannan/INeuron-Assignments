# %% [markdown]
# 1. Create an assert statement that throws an AssertionError if the variable spam is a negative
# integer.
#
# ans :
# spam = -10
# assert spam >= 0, "The variable spam is a negative integer."
#
# 2. Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain
# strings that are the same as each other, even if their cases are different (that is, &#39;hello&#39; and &#39;hello&#39; are
# considered the same, and &#39;goodbye&#39; and &#39;GOODbye&#39; are also considered the same).
#
# ans :
#
# eggs = "hello"
# bacon = "GOODbye"
#
# assert eggs.lower() != bacon.lower(), "The variables eggs and bacon contain the same string, even though the case is different."
#
# 3. Create an assert statement that throws an AssertionError every time.
#
# ans :
#
# assert False, "This assert statement will always trigger an AssertionError."
#
# 4. What are the two lines that must be present in your software in order to call logging.debug()?
#
# ans :
#
# import logging
#
# logging.basicConfig(level=logging.DEBUG)
#
# logging.debug("This is a debug message")
#
# 5. What are the two lines that your program must have in order to have logging.debug() send a
# logging message to a file named programLog.txt?
#
# ans :
#
# import logging
#
# logging.basicConfig(filename="programLog.txt", level=logging.DEBUG, filemode="w")
#
# logging.debug("This is a debug message")
#
# 6. What are the five levels of logging?
#
# ans :
#
# DEBUG=10.
# INFO=20.
# WARN=30.
# ERROR=40.
# CRITICAL=50.
#
#
# 7. What line of code would you add to your software to disable all logging messages?
#
# ans : getLogger('my-logger') logger. propagate = False # now if you use logger it will not log to console. This will prevent logging from being send to the upper logger that includes the console logging. Save this answer.
#
# 8.Why is using logging messages better than using print() to display the same message?
#
# ans : One of the advantages of using the logging module to track our codes is the ability to format the messages based on our needs. For example, in my code, I would like to log the date and time with appropriate messages.
#
# 9. What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?
#
# ans : Step Over is used for debugging the test steps line by line, but when the procedure is called, the entire procedure call will be executed as single step. The cursor never gets inside the procedure. Step Out: Step Out will enable, only after the debugging cursor gets inside a procedure.
#
# 10.After you click Continue, when will the debugger stop ?
#
# ans : Continue execution, only stop when a breakpoint is encountered. Set the next line that will be executed.
#
# 11. What is the concept of a breakpoint?
#
# ans : In software development, a breakpoint is an intentional stopping or pausing place in a program, put in place for debugging purposes. It is also sometimes simply referred to as a pause.
